# %%
import itertools
from myutils import Preprocessing 
from myutils import Datasets as ds
from myutils import Helpers 
from myutils import Complexity_Measures as cm
from myutils import QuatumCircuit
import numpy as np
import os
import pandas as pd
import tensorflow as tf
import random
import json
from matplotlib import pyplot as plt
import seaborn as sns

#Magic Command, so changes in myutils module are reloaded
# %load_ext autoreload
# %autoreload 1
# %aimport myutils

# %%
n_training = 100
n_test = 1000

# %%
data = ds.get_preprocessed_datasets("Autoencoder_small")["Autoencoder_small"]
for subset in ["6,9"]:

    np.random.seed(69)

    print(subset)

    data_subset = data[subset]
    
    #scale data 0, 2*np
    x_train = Preprocessing.minmax_scaler(data_subset["x_train"] , min = 0,max = 2 * np.pi)
    x_test = Preprocessing.minmax_scaler(data_subset["x_test"], min = 0,max = 2 * np.pi)

    #convert label from 0/1 to [0,1]/[1,0]
    y_train_quantum = Preprocessing.convertlabel_to_quantumstates(data_subset["y_train_binary"])
    y_test_quantum = Preprocessing.convertlabel_to_quantumstates(data_subset["y_test_binary"])


    # sampling and splitting 
    random.seed(69)

    x_train_subset, y_train_quantum_subset = Preprocessing.select_nExamples(x_train, y_train_quantum, n=n_training)
    x_test_subset, y_test_quantum_subset = Preprocessing.select_nExamples(x_test, y_test_quantum, n=n_test)


    
    qcircuit = QuatumCircuit(wires=10)
    hist,params = qcircuit.train(
        x_train=x_train_subset,
        y_train=y_train_quantum_subset,
        x_test=x_test_subset,
        y_test=y_test_quantum_subset,
        epochs=10,
        verbose=1)


    #save the hist

    Helpers.store(hist, "measure/qcircuit_loop/Autoencoder_small_10Wires/{}" .format(subset),"hist")
# Out:
# 6,9
# epoch 0: train_cost:63.372 train_acc:0.840 test_cost:417.128  test_acc:0.888
# epoch 1: train_cost:35.028 train_acc:0.920 test_cost:333.068  test_acc:0.916
# epoch 2: train_cost:29.540 train_acc:0.930 test_cost:314.796  test_acc:0.920
# epoch 3: train_cost:30.404 train_acc:0.940 test_cost:318.780  test_acc:0.927
# epoch 4: train_cost:30.196 train_acc:0.920 test_cost:310.936  test_acc:0.915
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/09/d62qr57n6dl6znjwx73740hw0000gn/T/ipykernel_1798/3529239053.py in <module>
#      26
#      27     qcircuit = QuatumCircuit(wires=10)
# ---> 28     hist,params = qcircuit.train(
#      29         x_train=x_train_subset,
#      30         y_train=y_train_quantum_subset,
#
# ~/Desktop/Uni_Stuff/KIT/Master/Module/QML/Code/masKIT/praktikum/myutils.py in train(self, x_train, y_train, x_test, y_test, epochs, verbose)
#     124             training_cost = 0
#     125             for datum, target in zip(x_train, y_train):
# --> 126                 self.parameters = optimizer.step(lambda weights: cost_fn(weights, datum, target), self.parameters)
#     127
#     128                 training_cost += cost_fn(self.parameters, datum, target)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/optimize/gradient_descent.py in step(self, objective_fn, grad_fn, *args, **kwargs)
#     127         """
#     128
# --> 129         g, _ = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#     130         new_args = self.apply_grad(g, args)
#     131
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/optimize/gradient_descent.py in compute_grad(objective_fn, args, kwargs, grad_fn)
#     156         """
#     157         g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 158         grad = g(*args, **kwargs)
#     159         forward = getattr(g, "forward", None)
#     160
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/_grad.py in __call__(self, *args, **kwargs)
#     118         """Evaluates the gradient function, and saves the function value
#     119         calculated during the forward pass in :attr:`.forward`."""
# --> 120         grad_value, ans = self._get_grad_fn(args)(*args, **kwargs)
#     121         self._forward = ans
#     122         return grad_value
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/autograd/wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/_grad.py in _grad_with_forward(fun, x)
#     143             )
#     144
# --> 145         grad_value = vjp(vspace(ans).ones())
#     146         return grad_value, ans
#     147
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/autograd/core.py in vjp(g)
#      12         def vjp(g): return vspace(x).zeros()
#      13     else:
# ---> 14         def vjp(g): return backward_pass(g, end_node)
#      15     return vjp, end_value
#      16
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/autograd/core.py in backward_pass(g, end_node)
#      19     for node in toposort(end_node):
#      20         outgrad = outgrads.pop(node)
# ---> 21         ingrads = node.vjp(outgrad[0])
#      22         for parent, ingrad in zip(node.parents, ingrads):
#      23             outgrads[parent] = add_outgrads(outgrads.get(parent), ingrad)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/autograd/core.py in <lambda>(g)
#      65                     "VJP of {} wrt argnum 0 not defined".format(fun.__name__))
#      66             vjp = vjpfun(ans, *args, **kwargs)
# ---> 67             return lambda g: (vjp(g),)
#      68         elif L == 2:
#      69             argnum_0, argnum_1 = argnums
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/autograd.py in grad_fn(dy)
#     186                 if _n == max_diff:
#     187                     with qml.tape.Unwrap(*tapes):
# --> 188                         vjp_tapes, processing_fn = qml.gradients.batch_vjp(
#     189                             tapes,
#     190                             dy,
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/gradients/vjp.py in batch_vjp(tapes, dys, gradient_fn, reduction, gradient_kwargs)
#     305     # Loop through the tapes and dys vector
#     306     for tape, dy in zip(tapes, dys):
# --> 307         g_tapes, fn = vjp(tape, dy, gradient_fn, gradient_kwargs)
#     308
#     309         reshape_info.append(len(g_tapes))
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/gradients/vjp.py in vjp(tape, dy, gradient_fn, gradient_kwargs)
#     174         pass
#     175
# --> 176     gradient_tapes, fn = gradient_fn(tape, **gradient_kwargs)
#     177
#     178     def processing_fn(results, num=None):
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/transforms/batch_transform.py in __call__(self, *targs, **tkwargs)
#     336             # Input is a quantum tape.
#     337             # tapes, fn = some_transform(tape, *transform_args)
# --> 338             return self._tape_wrapper(*targs, **tkwargs)(qnode)
#     339
#     340         if isinstance(qnode, (qml.QNode, qml.qnode_old.QNode, qml.ExpvalCost)):
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/transforms/batch_transform.py in <lambda>(tape)
#     424
#     425     def _tape_wrapper(self, *targs, **tkwargs):
# --> 426         return lambda tape: self.construct(tape, *targs, **tkwargs)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/transforms/batch_transform.py in construct(self, tape, *args, **kwargs)
#     408             tape = self.expand_fn(tape, *args, **kwargs)
#     409
# --> 410         tapes, processing_fn = self.transform_fn(tape, *args, **kwargs)
#     411
#     412         if processing_fn is None:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/gradients/parameter_shift.py in param_shift(tape, argnum, shift, gradient_recipes, fallback_fn, f0)
#     584         g_tapes, fn = var_param_shift(tape, argnum, shift, gradient_recipes, f0)
#     585     else:
# --> 586         g_tapes, fn = expval_param_shift(tape, argnum, shift, gradient_recipes, f0)
#     587
#     588     gradient_tapes.extend(g_tapes)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/gradients/parameter_shift.py in expval_param_shift(tape, argnum, shift, gradient_recipes, f0)
#     190         # generate the gradient tapes
#     191         gradient_coeffs.append(coeffs)
# --> 192         g_tapes = generate_shifted_tapes(tape, idx, shifts, multipliers)
#     193
#     194         gradient_tapes.extend(g_tapes)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/gradients/finite_difference.py in generate_shifted_tapes(tape, idx, shifts, multipliers)
#     169     for i, s in enumerate(shifts):
#     170         new_params = params.copy()
# --> 171         shifted_tape = tape.copy(copy_operations=True)
#     172
#     173         if multipliers is not None:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/tape/jacobian_tape.py in copy(self, copy_operations, tape_cls)
#      96
#      97     def copy(self, copy_operations=False, tape_cls=None):
# ---> 98         copied_tape = super().copy(copy_operations=copy_operations, tape_cls=tape_cls)
#      99         copied_tape.jacobian_options = self.jacobian_options
#     100         return copied_tape
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/tape/tape.py in copy(self, copy_operations, tape_cls)
#    1256             # unless modified.
#    1257             tape._prep = [copy.copy(op) for op in self._prep]
# -> 1258             tape._ops = [copy.copy(op) for op in self._ops]
#    1259             tape._measurements = [copy.copy(op) for op in self._measurements]
#    1260         else:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/tape/tape.py in <listcomp>(.0)
#    1256             # unless modified.
#    1257             tape._prep = [copy.copy(op) for op in self._prep]
# -> 1258             tape._ops = [copy.copy(op) for op in self._ops]
#    1259             tape._measurements = [copy.copy(op) for op in self._measurements]
#    1260         else:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/copy.py in copy(x)
#      82     copier = getattr(cls, "__copy__", None)
#      83     if copier is not None:
# ---> 84         return copier(x)
#      85
#      86     reductor = dispatch_table.get(cls)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/operation.py in __copy__(self)
#     271         copied_op.data = self.data.copy()
#     272         for attr, value in vars(self).items():
# --> 273             if attr != "data":
#     274                 setattr(copied_op, attr, value)
#     275
#
# KeyboardInterrupt:
