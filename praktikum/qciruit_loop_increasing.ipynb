# %%
import itertools
from myutils import Preprocessing 
from myutils import Datasets as ds
from myutils import Helpers 
from myutils import Complexity_Measures as cm
from myutils import QuatumCircuit
import numpy as np
import os
import pandas as pd
import tensorflow as tf
import random
import json
from matplotlib import pyplot as plt
import seaborn as sns

#Magic Command, so changes in myutils module are reloaded
# %load_ext autoreload
# %autoreload 1
# %aimport myutils

# %%
n_training = 100
n_test = 1000

# %%
for featurenum in ["13"]:
    
    preprocessing = "Autoencoder"
    subset = "6,9"
    np.random.seed(1337)
    
    x_train = np.load("data/increasingFeature/{}/{}/{}/x_train.npy".format(preprocessing,featurenum, subset))
    x_test = np.load("data/increasingFeature/{}/{}/{}/x_test.npy".format(preprocessing,featurenum, subset))
    y_train_binary = np.load("data/increasingFeature/{}/{}/{}/y_train_binary.npy".format(preprocessing,featurenum, subset))
    y_test_binary = np.load("data/increasingFeature/{}/{}/{}/y_test_binary.npy".format(preprocessing,featurenum, subset))

    print(subset, featurenum)
    
    #scale data 0, 2*np
    x_train = Preprocessing.minmax_scaler(x_train , min = 0,max = 2 * np.pi)
    x_test = Preprocessing.minmax_scaler(x_test, min = 0,max = 2 * np.pi)

    #convert label from 0/1 to [0,1]/[1,0]
    y_train_quantum = Preprocessing.convertlabel_to_quantumstates(y_train_binary)
    y_test_quantum = Preprocessing.convertlabel_to_quantumstates(y_test_binary)


    # sampling and splitting 
    random.seed(1337)

    x_train_subset, y_train_quantum_subset = Preprocessing.select_nExamples(x_train, y_train_quantum, n=n_training)
    x_test_subset, y_test_quantum_subset = Preprocessing.select_nExamples(x_test, y_test_quantum, n=n_test)

    
    qcircuit = QuatumCircuit(wires=int(featurenum),layers=8)
    hist,params = qcircuit.train(
        x_train=x_train_subset,
        y_train=y_train_quantum_subset,
        x_test=x_test_subset,
        y_test=y_test_quantum_subset,
        epochs=10,
        verbose=1)


    #save the hist

    Helpers.store(hist, "measure/qcircuit_increasing/Autoencoder_layer8/{}/{}" .format(featurenum,subset),"hist")
# Out:
# 6,9 13
# epoch 0: train_cost:73.136 train_acc:0.710 test_cost:460.676  test_acc:0.830
# epoch 1: train_cost:44.632 train_acc:0.830 test_cost:431.468  test_acc:0.837
# epoch 2: train_cost:43.356 train_acc:0.850 test_cost:373.992  test_acc:0.871
# epoch 3: train_cost:36.084 train_acc:0.900 test_cost:332.528  test_acc:0.929
# epoch 4: train_cost:31.304 train_acc:0.930 test_cost:310.684  test_acc:0.933
# epoch 5: train_cost:27.588 train_acc:0.950 test_cost:246.020  test_acc:0.957
# epoch 6: train_cost:23.812 train_acc:0.950 test_cost:235.828  test_acc:0.966
# epoch 7: train_cost:25.652 train_acc:0.950 test_cost:324.276  test_acc:0.954
# epoch 8: train_cost:23.944 train_acc:0.950 test_cost:241.956  test_acc:0.957
# epoch 9: train_cost:24.012 train_acc:0.950 test_cost:233.040  test_acc:0.957

# %%
for featurenum in os.listdir("data/increasingFeature/PCA"):
    
    preprocessing = "Autoencoder"
    subset = "6,9"
    np.random.seed(1337)
    
    x_train = np.load("data/increasingFeature/{}/{}/{}/x_train.npy".format(preprocessing,featurenum, subset))
    x_test = np.load("data/increasingFeature/{}/{}/{}/x_test.npy".format(preprocessing,featurenum, subset))
    y_train_binary = np.load("data/increasingFeature/{}/{}/{}/y_train_binary.npy".format(preprocessing,featurenum, subset))
    y_test_binary = np.load("data/increasingFeature/{}/{}/{}/y_test_binary.npy".format(preprocessing,featurenum, subset))

    print(subset, featurenum)
    
    #scale data 0, 2*np
    x_train = Preprocessing.minmax_scaler(x_train , min = 0,max = 2 * np.pi)
    x_test = Preprocessing.minmax_scaler(x_test, min = 0,max = 2 * np.pi)

    #convert label from 0/1 to [0,1]/[1,0]
    y_train_quantum = Preprocessing.convertlabel_to_quantumstates(y_train_binary)
    y_test_quantum = Preprocessing.convertlabel_to_quantumstates(y_test_binary)


    # sampling and splitting 
    random.seed(1337)

    x_train_subset, y_train_quantum_subset = Preprocessing.select_nExamples(x_train, y_train_quantum, n=n_training)
    x_test_subset, y_test_quantum_subset = Preprocessing.select_nExamples(x_test, y_test_quantum, n=n_test)

    
    qcircuit = QuatumCircuit(wires=int(featurenum))
    hist,params = qcircuit.train(
        x_train=x_train_subset,
        y_train=y_train_quantum_subset,
        x_test=x_test_subset,
        y_test=y_test_quantum_subset,
        epochs=10,
        verbose=1)


    #save the hist

    Helpers.store(hist, "measure/qcircuit_increasing/Autoencoder/{}/{}" .format(featurenum,subset),"hist")
# Out:
# 6,9 9
# epoch 0: train_cost:79.108 train_acc:0.810 test_cost:542.376  test_acc:0.824
# epoch 1: train_cost:44.404 train_acc:0.880 test_cost:428.168  test_acc:0.883
# epoch 2: train_cost:40.076 train_acc:0.920 test_cost:392.768  test_acc:0.891
# epoch 3: train_cost:39.500 train_acc:0.920 test_cost:393.448  test_acc:0.910
# epoch 4: train_cost:39.096 train_acc:0.930 test_cost:376.744  test_acc:0.918
# epoch 5: train_cost:37.044 train_acc:0.930 test_cost:348.564  test_acc:0.929
# epoch 6: train_cost:36.092 train_acc:0.950 test_cost:337.148  test_acc:0.931
# epoch 7: train_cost:35.912 train_acc:0.940 test_cost:342.920  test_acc:0.936
# epoch 8: train_cost:34.584 train_acc:0.950 test_cost:345.884  test_acc:0.940
# epoch 9: train_cost:35.872 train_acc:0.950 test_cost:325.404  test_acc:0.944
# 6,9 11
# epoch 0: train_cost:71.588 train_acc:0.760 test_cost:510.456  test_acc:0.847
# epoch 1: train_cost:31.212 train_acc:0.920 test_cost:268.488  test_acc:0.952
# epoch 2: train_cost:18.116 train_acc:0.980 test_cost:229.592  test_acc:0.966
# epoch 3: train_cost:17.392 train_acc:0.980 test_cost:221.392  test_acc:0.972
# epoch 4: train_cost:17.684 train_acc:0.990 test_cost:229.792  test_acc:0.971
# epoch 5: train_cost:17.488 train_acc:0.980 test_cost:216.776  test_acc:0.972
# epoch 6: train_cost:16.176 train_acc:0.990 test_cost:227.992  test_acc:0.978
# epoch 7: train_cost:17.460 train_acc:0.990 test_cost:210.260  test_acc:0.976
# epoch 8: train_cost:17.412 train_acc:0.990 test_cost:242.264  test_acc:0.978
# epoch 9: train_cost:17.396 train_acc:0.990 test_cost:221.880  test_acc:0.979
# 6,9 7
# epoch 0: train_cost:94.644 train_acc:0.630 test_cost:853.480  test_acc:0.616
# epoch 1: train_cost:77.428 train_acc:0.650 test_cost:796.964  test_acc:0.657
# epoch 2: train_cost:70.288 train_acc:0.690 test_cost:745.552  test_acc:0.696
# epoch 3: train_cost:69.180 train_acc:0.710 test_cost:733.672  test_acc:0.716
# epoch 4: train_cost:66.192 train_acc:0.760 test_cost:714.564  test_acc:0.741
# epoch 5: train_cost:66.916 train_acc:0.760 test_cost:696.124  test_acc:0.752
# epoch 6: train_cost:64.428 train_acc:0.760 test_cost:689.116  test_acc:0.743
# epoch 7: train_cost:63.172 train_acc:0.780 test_cost:677.920  test_acc:0.747
# epoch 8: train_cost:63.580 train_acc:0.760 test_cost:667.572  test_acc:0.745
# epoch 9: train_cost:61.308 train_acc:0.790 test_cost:661.172  test_acc:0.748
# 6,9 13
# epoch 0: train_cost:72.912 train_acc:0.760 test_cost:694.184  test_acc:0.717
# epoch 1: train_cost:62.440 train_acc:0.750 test_cost:683.676  test_acc:0.714
# epoch 2: train_cost:58.900 train_acc:0.770 test_cost:634.000  test_acc:0.729
# epoch 3: train_cost:54.196 train_acc:0.770 test_cost:593.704  test_acc:0.755
# epoch 4: train_cost:51.916 train_acc:0.800 test_cost:565.896  test_acc:0.766
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/09/d62qr57n6dl6znjwx73740hw0000gn/T/ipykernel_16305/3447537866.py in <module>
#      29
#      30     qcircuit = QuatumCircuit(wires=int(featurenum))
# ---> 31     hist,params = qcircuit.train(
#      32         x_train=x_train_subset,
#      33         y_train=y_train_quantum_subset,
#
# ~/Desktop/Uni_Stuff/KIT/Master/Module/QML/Code/masKIT/praktikum/myutils.py in train(self, x_train, y_train, x_test, y_test, epochs, verbose)
#     130
#     131
# --> 132             test_cost, test_correct_count = self.overall_cost_and_correct(cost_fn, self.parameters, x_test, y_test)
#     133
#     134             hist['accuracy'].append(training_correct_count / len(x_train))
#
# ~/Desktop/Uni_Stuff/KIT/Master/Module/QML/Code/masKIT/praktikum/myutils.py in overall_cost_and_correct(self, cost_fn, params, data, targets)
#      74         for datum, target in zip(data, targets):
#      75             cost += cost_fn(params, datum, target)
# ---> 76             correct_count += int(self.correctly_classified(params, datum, target))
#      77         return cost, correct_count
#      78
#
# ~/Desktop/Uni_Stuff/KIT/Master/Module/QML/Code/masKIT/praktikum/myutils.py in correctly_classified(self, params, data, target)
#      63     # some helpers
#      64     def correctly_classified(self, params, data, target):
# ---> 65         prediction = self.training_circuit(params, data)
#      66         if prediction < 0 and target[0] > 0:
#      67             return True
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     559         tapes, processing_fn = self.device.batch_transform(self.tape)
#     560
# --> 561         res = qml.execute(
#     562             tapes,
#     563             device=self.device,
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/__init__.py in execute(tapes, device, gradient_fn, interface, mode, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion)
#     388         ) from e
#     389
# --> 390     res = _execute(
#     391         tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n=1, max_diff=max_diff, mode=_mode
#     392     )
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/autograd.py in execute(tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n, max_diff, mode)
#      62     )
#      63
# ---> 64     return _execute(
#      65         parameters,
#      66         tapes=tapes,
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/autograd.py in _execute(parameters, tapes, device, execute_fn, gradient_fn, gradient_kwargs, _n, max_diff)
#     106     """
#     107     with qml.tape.Unwrap(*tapes):
# --> 108         res, jacs = execute_fn(tapes, **gradient_kwargs)
#     109
#     110     for i, r in enumerate(res):
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/__init__.py in wrapper(tapes, **kwargs)
#     166         else:
#     167             # execute all unique tapes that do not exist in the cache
# --> 168             res = fn(execution_tapes.values(), **kwargs)
#     169
#     170         final_res = []
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/interfaces/batch/__init__.py in fn(tapes, **kwargs)
#     118         def fn(tapes, **kwargs):  # pylint: disable=function-redefined
#     119             tapes = [expand_fn(tape) for tape in tapes]
# --> 120             return original_fn(tapes, **kwargs)
#     121
#     122     @wraps(fn)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/_qubit_device.py in batch_execute(self, circuits)
#     276             self.reset()
#     277
# --> 278             res = self.execute(circuit)
#     279             results.append(res)
#     280
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/_qubit_device.py in execute(self, circuit, **kwargs)
#     192
#     193         # apply all circuit operations
# --> 194         self.apply(circuit.operations, rotations=circuit.diagonalizing_gates, **kwargs)
#     195
#     196         # generate computational basis samples
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/devices/default_qubit.py in apply(self, operations, rotations, **kwargs)
#     214                 self._apply_basis_state(operation.parameters[0], operation.wires)
#     215             else:
# --> 216                 self._state = self._apply_operation(self._state, operation)
#     217
#     218         # store the pre-rotated state
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/devices/default_qubit.py in _apply_operation(self, state, operation)
#     239             return self._apply_ops[operation.base_name](state, axes, inverse=operation.inverse)
#     240
# --> 241         matrix = self._get_unitary_matrix(operation)
#     242
#     243         if operation in diagonal_in_z_basis:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/devices/default_qubit.py in _get_unitary_matrix(self, unitary)
#     546             return unitary.eigvals
#     547
# --> 548         return unitary.matrix
#     549
#     550     @classmethod
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/operation.py in matrix(self)
#     779     @property
#     780     def matrix(self):
# --> 781         op_matrix = self._matrix(*self.parameters)
#     782
#     783         if self.inverse:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/ops/qubit/parametric_ops.py in _matrix(cls, *params)
#      73         js = -1j * s
#      74
# ---> 75         return qml.math.diag([c, c]) + qml.math.stack(
#      76             [qml.math.stack([0, js]), qml.math.stack([js, 0])]
#      77         )
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/math/multi_dispatch.py in stack(values, axis)
#     391            [5.00e+00, 8.00e+00, 1.01e+02]], dtype=float32)>
#     392     """
# --> 393     interface = _multi_dispatch(values)
#     394     values = np.coerce(values, like=interface)
#     395     return np.stack(values, axis=axis, like=interface)
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/math/multi_dispatch.py in _multi_dispatch(values)
#      51         values = np.asarray(values)
#      52
# ---> 53     interfaces = {get_interface(v) for v in values}
#      54
#      55     if len(set(interfaces) - {"numpy", "scipy", "autograd"}) > 1:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/math/multi_dispatch.py in <setcomp>(.0)
#      51         values = np.asarray(values)
#      52
# ---> 53     interfaces = {get_interface(v) for v in values}
#      54
#      55     if len(set(interfaces) - {"numpy", "scipy", "autograd"}) > 1:
#
# ~/miniforge3/envs/tfm1/lib/python3.9/site-packages/pennylane/math/utils.py in get_interface(tensor)
#     188     'autograd'
#     189     """
# --> 190     namespace = tensor.__class__.__module__.split(".")[0]
#     191
#     192     if namespace in ("pennylane", "autograd"):
#
# KeyboardInterrupt:
